# %% [markdown]
# <a href="https://colab.research.google.com/github/NewtonSawitta/bsc_dpdm22/blob/main/%5Bdataprep1%5D_property_estimator_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #สรุปข้อมูลของนักประเมินแต่ละคน โดยพิจารณาจาก ความมั่นใจในการประเมิน ประเมินราคาซื้อ-ขาย ให้คะแนนหลักทรัพย์

# %% [markdown]
# ##import data

# %%
import pandas as pd

# %%
data = pd.read_excel("คำตอบนักประเมิน.xlsx",sheet_name='บ้าน')
data.head(5)
# Out:
#    ID ผู้ประเมิน                              post id property_type  \
# 0              1   https://nayoo.co/khonkaen/posts/25    บ้านเดี่ยว
# 1              2   https://nayoo.co/khonkaen/posts/25    บ้านเดี่ยว
# 2              1   https://nayoo.co/khonkaen/posts/33    บ้านเดี่ยว
# 3              2   https://nayoo.co/khonkaen/posts/33    บ้านเดี่ยว
# 4              1  https://nayoo.co/khonkaen/posts/495    บ้านเดี่ยว
#
#   ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# 0                        มั่นใจ   2700000.0            2500000.0
# 1                        มั่นใจ   2700000.0            2700000.0
# 2                        มั่นใจ   2600000.0            2200000.0
# 3                        มั่นใจ   2600000.0            2400000.0
# 4                        มั่นใจ   5900000.0            5000000.0
#
#                       ปัจจัยในการประเมินราคาซื้อ-ขาย  \
# 0                                       5,000-15,000
# 1  โครงการนี้ราคาเสนอขาย 2,500,000-3,000,000 บาท/...
# ...

# %% [markdown]
# ##ผู้ประเมินคนที่ 1

# %%
id_ass01 = data[data['ID ผู้ประเมิน']==1]
id_ass01.head()
# Out:
#    ID ผู้ประเมิน                              post id property_type  \
# 0              1   https://nayoo.co/khonkaen/posts/25    บ้านเดี่ยว
# 2              1   https://nayoo.co/khonkaen/posts/33    บ้านเดี่ยว
# 4              1  https://nayoo.co/khonkaen/posts/495    บ้านเดี่ยว
# 6              1  https://nayoo.co/khonkaen/posts/564    บ้านเดี่ยว
# 8              1  https://nayoo.co/khonkaen/posts/566    บ้านเดี่ยว
#
#   ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# 0                        มั่นใจ   2700000.0            2500000.0
# 2                        มั่นใจ   2600000.0            2200000.0
# 4                        มั่นใจ   5900000.0            5000000.0
# 6                        มั่นใจ   4400000.0            3500000.0
# 8                        มั่นใจ   2750000.0            2500000.0
#
#   ปัจจัยในการประเมินราคาซื้อ-ขาย เหตุผลไม่มั่นใจราคาประเมิน  \
# 0                   5,000-15,000                        NaN
# ...

# %%
id_ass01.describe()
# Out:
#        ID ผู้ประเมิน    ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  Unnamed: 9  \
# count          100.0  1.000000e+02         1.000000e+02         0.0
# mean             1.0  4.316360e+06         3.938500e+06         NaN
# std              0.0  2.865391e+06         2.368553e+06         NaN
# min              1.0  3.900000e+05         6.000000e+05         NaN
# 25%              1.0  2.892750e+06         2.775000e+06         NaN
# 50%              1.0  3.962000e+06         3.600000e+06         NaN
# 75%              1.0  5.000000e+06         4.500000e+06         NaN
# max              1.0  2.094900e+07         1.600000e+07         NaN
#
#        Unnamed: 10  Unnamed: 11  Unnamed: 12  Unnamed: 13
# count          0.0          0.0          0.0          1.0
# mean           NaN          NaN          NaN        100.0
# std            NaN          NaN          NaN          NaN
# min            NaN          NaN          NaN        100.0
# 25%            NaN          NaN          NaN        100.0
# ...

# %% [markdown]
# ###ความมั่นใจในการเมินราคาทรัพย์

# %%
id_ass01['ความมั่นใจในการเมินราคาทรัพย์'].value_counts()
# Out:
# มั่นใจ    100
# Name: ความมั่นใจในการเมินราคาทรัพย์, dtype: int64

# %% [markdown]
# ###ประเมินราคาซื้อ-ขาย

# %%
id_ass01['ประเมินราคาซื้อ-ขาย'].value_counts()
# Out:
# 3500000.0     14
# 4500000.0      9
# 4200000.0      8
# 4000000.0      5
# 2500000.0      4
# 2800000.0      4
# 3800000.0      4
# 1200000.0      4
# 5200000.0      4
# 1800000.0      3
# 5000000.0      3
# 3600000.0      3
# 7500000.0      3
# 2700000.0      2
# 5500000.0      2
# 2200000.0      2
# 3300000.0      2
# 3000000.0      2
# 3200000.0      2
# 2000000.0      2
# 6200000.0      1
# 15000000.0     1
# 2600000.0      1
# 5600000.0      1
# 4700000.0      1
# 4300000.0      1
# 4400000.0      1
# 600000.0       1
# 1600000.0      1
# 8000000.0      1
# 16000000.0     1
# 750000.0       1
# 12000000.0     1
# 1500000.0      1
# 800000.0       1
# 700000.0       1
# 1700000.0      1
# 4800000.0      1
# Name: ประเมินราคาซื้อ-ขาย, dtype: int64

# %% [markdown]
# ###ให้คะแนนหลักทรัพย์

# %%
id_ass01['ให้คะแนนทรัพย์'].value_counts()
# Out:
# 2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี    54
# 3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน     43
# 4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน       2
# 1 ขายไม่ได้แน่นอน                      1
# Name: ให้คะแนนทรัพย์, dtype: int64

# %% [markdown]
# ##ผู้ประเมินคนที่ 2

# %%
id_ass02 = data[data['ID ผู้ประเมิน']==2]
id_ass02.head()
# Out:
#    ID ผู้ประเมิน                              post id property_type  \
# 1              2   https://nayoo.co/khonkaen/posts/25    บ้านเดี่ยว
# 3              2   https://nayoo.co/khonkaen/posts/33    บ้านเดี่ยว
# 5              2  https://nayoo.co/khonkaen/posts/495    บ้านเดี่ยว
# 7              2  https://nayoo.co/khonkaen/posts/564    บ้านเดี่ยว
# 9              2  https://nayoo.co/khonkaen/posts/566    บ้านเดี่ยว
#
#   ความมั่นใจในการเมินราคาทรัพย์  ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  \
# 1                        มั่นใจ   2700000.0            2700000.0
# 3                        มั่นใจ   2600000.0            2400000.0
# 5                        มั่นใจ   5900000.0            9000000.0
# 7                        มั่นใจ   4400000.0            3700000.0
# 9                        มั่นใจ   2750000.0            2500000.0
#
#                       ปัจจัยในการประเมินราคาซื้อ-ขาย  \
# 1  โครงการนี้ราคาเสนอขาย 2,500,000-3,000,000 บาท/...
# 3   ราคาเสนอขายประมาณ 2,200,000 - 2,500,000 บาท/หลัง
# ...

# %%
id_ass02.describe()
# Out:
#        ID ผู้ประเมิน    ราคาทรัพย์  ประเมินราคาซื้อ-ขาย  Unnamed: 9  \
# count           90.0  9.000000e+01         8.900000e+01         0.0
# mean             2.0  4.240733e+06         4.153258e+06         NaN
# std              0.0  2.714815e+06         2.386901e+06         NaN
# min              2.0  3.900000e+05         9.900000e+05         NaN
# 25%              2.0  2.860000e+06         2.600000e+06         NaN
# 50%              2.0  4.000000e+06         3.900000e+06         NaN
# 75%              2.0  5.000000e+06         4.900000e+06         NaN
# max              2.0  2.094900e+07         1.700000e+07         NaN
#
#        Unnamed: 10  Unnamed: 11  Unnamed: 12  Unnamed: 13
# count          0.0          0.0          0.0          0.0
# mean           NaN          NaN          NaN          NaN
# std            NaN          NaN          NaN          NaN
# min            NaN          NaN          NaN          NaN
# 25%            NaN          NaN          NaN          NaN
# ...

# %% [markdown]
# ###ความมั่นใจในการเมินราคาทรัพย์

# %%
id_ass02['ความมั่นใจในการเมินราคาทรัพย์'].value_counts()
# Out:
# มั่นใจ       89
# ไม่มั่นใจ     1
# Name: ความมั่นใจในการเมินราคาทรัพย์, dtype: int64

# %% [markdown]
# ###ประเมินราคาซื้อ-ขาย

# %%
id_ass02['ประเมินราคาซื้อ-ขาย'].value_counts()
# Out:
# 4500000.0     8
# 3500000.0     5
# 4000000.0     5
# 5000000.0     5
# 2500000.0     4
# 6000000.0     3
# 3200000.0     3
# 1000000.0     3
# 4200000.0     3
# 2200000.0     3
# 2800000.0     3
# 3900000.0     3
# 3600000.0     3
# 9000000.0     3
# 3000000.0     2
# 2000000.0     2
# 1200000.0     2
# 4900000.0     2
# 8000000.0     2
# 6500000.0     2
# 4800000.0     2
# 5500000.0     2
# 3700000.0     2
# 7000000.0     1
# 1900000.0     1
# 2300000.0     1
# 7400000.0     1
# 17000000.0    1
# 1350000.0     1
# 2700000.0     1
# 10000000.0    1
# 2600000.0     1
# 1300000.0     1
# 3800000.0     1
# 2400000.0     1
# 990000.0      1
# 1800000.0     1
# 4400000.0     1
# 5900000.0     1
# 1400000.0     1
# Name: ประเมินราคาซื้อ-ขาย, dtype: int64

# %% [markdown]
# ###ให้คะแนนหลักทรัพย์

# %%
id_ass02['ให้คะแนนทรัพย์'].value_counts()
# Out:
# 3 ขายได้ ใช้ระยะเวลา 7 - 12 เดือน     64
# 4 ขายได้ ใช้ระยะเวลา 4 - 6 เดือน      23
# 5 ขายง่าย ใช้ระยะเวลา 1 - 3 เดือน      1
# 2 ขายได้ยาก ใช้ระยะเวลามากว่า 1 ปี     1
# Name: ให้คะแนนทรัพย์, dtype: int64

# %% [markdown]
# ##เปรียบเทียบความแตกต่างในการประเมินราคาทรัพย์แต่ละทรัพย์ของนักประเมินแต่ละคนและของราคาตั้งขาย

# %% [markdown]
# * ใช้ MAPE เป็นเกณฑ์ในการเปรียบเทียบ

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##Map คนที่ 1 กับคนที่ 2

# %%
id_ass02['ประเมิน1'] = id_ass02['post id'].map(id_ass01.set_index('post id')['ประเมินราคาซื้อ-ขาย']);
id_ass02
# Out:
# <ipython-input-17-f5c1feeceb00>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   id_ass02['ประเมิน1'] = id_ass02['post id'].map(id_ass01.set_index('post id')['ประเมินราคาซื้อ-ขาย']);
#      ID ผู้ประเมิน                                post id property_type  \
# 1                2     https://nayoo.co/khonkaen/posts/25    บ้านเดี่ยว
# 3                2     https://nayoo.co/khonkaen/posts/33    บ้านเดี่ยว
# 5                2    https://nayoo.co/khonkaen/posts/495    บ้านเดี่ยว
# 7                2    https://nayoo.co/khonkaen/posts/564    บ้านเดี่ยว
# 9                2    https://nayoo.co/khonkaen/posts/566    บ้านเดี่ยว
# ..             ...                                    ...           ...
# ...

# %%
id_ass02[['post id','ราคาทรัพย์']]
# Out:
#                                    post id  ราคาทรัพย์
# 1       https://nayoo.co/khonkaen/posts/25   2700000.0
# 3       https://nayoo.co/khonkaen/posts/33   2600000.0
# 5      https://nayoo.co/khonkaen/posts/495   5900000.0
# 7      https://nayoo.co/khonkaen/posts/564   4400000.0
# 9      https://nayoo.co/khonkaen/posts/566   2750000.0
# ..                                     ...         ...
# 185  https://nayoo.co/khonkaen/posts/19495   5500000.0
# 186  https://nayoo.co/khonkaen/posts/19496   7911000.0
# 187     https://nayoo.co/khonkaen/posts/20   2000000.0
# 188     https://nayoo.co/khonkaen/posts/31   4000000.0
# 189    https://nayoo.co/khonkaen/posts/570   1375000.0
#
# [90 rows x 2 columns]
